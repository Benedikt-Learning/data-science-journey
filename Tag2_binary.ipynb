# %% [markdown]
# <a href="https://colab.research.google.com/github/Benedikt-Learning/data-science-journey/blob/main/Tag2_binary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def binary():
  n = int(input("Gib eine Zahl ein: "))
  temp = divmod(n,2)
  n = temp[0]
  s = temp[1]
  while temp[0] > 0:
    temp = divmod(n, 2)
    n = temp[0]
    s = str(temp[1]) + str(s)
  print(s)



binary()
# Out:
# Gib eine Zahl ein: 21
# 10101
