# %% [markdown]
# <a href="https://colab.research.google.com/github/Benedikt-Learning/data-science-journey/blob/main/Tag2_Umsatzliste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
def umsatz(liste):
  max_monat = []
  mehr_als_durchschnitt = []
  durchschnitt = sum(liste) / len(liste)
  max_monat = max(liste)
  min_monat = min(liste)
  proz_unterschied = (max_monat - min_monat) / max_monat
  mehr_als_durchschnitt = [x for x in liste if x > durchschnitt]
  print(max_monat)
  print(mehr_als_durchschnitt)
  print(max_monat)
  print(min_monat)
  print(proz_unterschied)



umsatzliste = []
for x in range(0, 1000):
  umsatzliste.append(random.randint(800, 2500))
test = umsatz(umsatzliste)
# Out:
# 2498
# ...
