# %% [markdown]
# <a href="https://colab.research.google.com/github/Benedikt-Learning/data-science-journey/blob/main/Tag1_Planer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Willkommen zum Tagesplaner")
anzahl_Aufgaben = int(input("Wie viele Aufgaben möchtest du machen?"))
aufgaben = []
for i in range(anzahl_Aufgaben):
  aufgaben.append(input("Was ist deine Aufgabe?"))

print("Deine Aufgaben sind: ")
for j in range(anzahl_Aufgaben):
  print(aufgaben[j])
# Out:
# Willkommen zum Tagesplaner
# Wie viele Aufgaben möchtest du machen?5
# Was ist deine Aufgabe?Spielen
# Was ist deine Aufgabe?Kochen
# Was ist deine Aufgabe?Malen
# Was ist deine Aufgabe?Lesen
# Was ist deine Aufgabe?Reden
# Deine Aufgaben sind:
# Spielen
# Kochen
# Malen
# Lesen
# Reden
